# %% [markdown]
# # Assignment #10 - Data Gathering and Warehousing - DSSA-5102
#
# Instructor: Melissa Laurino</br>
# Spring 2024</br>
#
# Name: Udoy Chowdhury
# </br>
# Date: 2024-04-04
# <br>
# <br>
# **At this time in the semester:** <br>
# --We have explored a dataset. <br>
# --We have cleaned our dataset. <br>
# --We created a Github account with a repository for this class and included a Metadata file about our data. <br>
# --We introduced general and more advanced SQL syntax, queries, and applications in R.<br>
# --Created our own database from scratch in R using libraries RMariaDB and RSQLite <br>
# --Populated our databases we created from scratch<br>
# --Created a visual enhanced entity relationship diagram for our database
# <br>
#
# **Objective**: Connect to a website using an API. Gather live data from a website using an API.<br>
# **If you would like to conntect to a different social media platform that you use instead of INaturalist, that is totally fine as long as you commnet/explain your thought process!**<br>
# <br>
# **iNaturalist**: iNaturalist is a community of citizen scientists that encourages accurate data collection and species identification of the natural world.
# <br>
# No observations of captive plants or animals should be included in the iNaturalist data. Research grade observaitons have been verified by the community in terms of species ID, location, etc. Research grade observations have been verified by the community of experts in that field.
# <br>
# API's are useful to bridge the gap between manually querying and downloading data, and then uploading them into R/Python, by just working with the live data directly in your platform of choice.
#
# Follow the instructions below to complete the assignment. Answer any questions in markdown cell boxes. Be sure to comment all code.

# %% [markdown]
# Learn more about the iNaturalist API: https://api.inaturalist.org/v1/docs/#!/Observations/get_observations_observers<br><br>
#
# R packages for working with iNaturalist API to gather live data:<br>
# spocc: https://cran.r-project.org/web/packages/spocc/spocc.pdf <br>
# rinat: https://cran.r-project.org/web/packages/rinat/rinat.pdf

# %% [markdown]
# ## Accessing iNaturalist data via API from scratch:
#
# ***Obtaining an iNaturalist API token:***<br>
# Create a username and password and **log in** to www.inaturalist.org using those credentials.<br>
# In the same browser, obtain your INaturalist API Token by using this link: https://www.inaturalist.org/users/api_token<br>
# Do not click this link more than once or it will regenerate your token!<br>
# With iNaturalist, this token is <b>ONLY<b> valid for 24hrs.

# %%
import requests

#Enter your generated API token here:
api_token = 'eyJhbGciOiJIUzUxMiJ9.eyJ1c2VyX2lkIjo3NzQ5MjE3LCJleHAiOjE3MTIzNTUyNjR9.gAaiNTJG61BjTL9IFzsRgypwmTR0bS4tiu3QYRKdpwaQoyROgaBbDy_mcxTK6mPinmWONSUdOK21q0kscqPSIg'

#Define the iNaturalist API endpoint. This is defined by www.inaturalist.org.
inat_api_url = "https://api.inaturalist.org/v1"

# %%
#Set the API token in the HTTP headers
headers = {
    'Authorization': f'Bearer {api_token}',
}

# Define Endpoint
endpointurl = f'{inat_api_url}/users/me'

# Make the GET request to the API
response = requests.get(endpointurl, headers=headers)

#Check if the API request was successful
if response.status_code == 200:
    # Put response into a variable
    user_info = response.json()
    print(user_info)
# Out:
# {'total_results': 1, 'page': 1, 'per_page': 1, 'results': [{'id': 7749217, 'login': 'udoychowdhury', 'spam': False, 'suspended': False, 'created_at': '2024-01-25T01:38:58+00:00', 'login_autocomplete': 'udoychowdhury', 'login_exact': 'udoychowdhury', 'name': None, 'name_autocomplete': None, 'orcid': None, 'icon': None, 'observations_count': 0, 'identifications_count': 0, 'journal_posts_count': 0, 'activity_count': 0, 'species_count': 0, 'universal_search_rank': 0, 'roles': [], 'site_id': 1, 'updated_at': '2024-04-04T22:14:24+00:00', 'description': None, 'search_place_id': None, 'confirmed_at': '2024-01-25T01:41:56+00:00', 'confirmation_sent_at': '2024-01-25T01:38:58+00:00', 'time_zone': 'Eastern Time (US & Canada)', 'email': 'uchowdhury28@gmail.com', 'unconfirmed_email': None, 'locale': 'en-US', 'place_id': None, 'pi_consent': True, 'data_transfer_consent': True, 'prefers_automatic_taxonomic_changes': True, 'prefers_comment_email_notification': True, 'prefers_common_names': True, 'prefers_community_taxa': True, 'prefers_identification_email_notification': True, 'prefers_mention_email_notification': True, 'prefers_message_email_notification': True, 'prefers_monthly_supporter_badge': False, 'prefers_no_email': False, 'prefers_no_tracking': False, 'preferred_observation_fields_by': 'anyone', 'preferred_observation_license': 'CC-BY-NC', 'preferred_photo_license': 'CC-BY-NC', 'prefers_project_added_your_observation_email_notification': True, 'preferred_project_addition_by': 'any', 'prefers_project_curator_change_email_notification': True, 'prefers_project_journal_post_email_notification': True, 'prefers_receive_mentions': True, 'prefers_redundant_identification_notifications': True, 'prefers_scientific_name_first': False, 'preferred_sound_license': 'CC-BY-NC', 'prefers_taxon_change_email_notification': True, 'prefers_taxon_or_place_observation_email_notification': True, 'prefers_user_observation_email_notification': True, 'muted_user_ids': [], 'blocked_user_ids': [], 'privileges': [], 'monthly_supporter': False, 'taxon_name_priorities': [], 'site': {'id': 1, 'name': 'iNaturalist', 'url': 'https://www.inaturalist.org', 'place_id': None, 'locale': None, 'site_name_short': 'iNat', 'icon_url': 'https://static.inaturalist.org/sites/1-logo_square.png'}, 'icon_url': None}]}

# %%
#Another function to double check API status - we can never be too sure! 

# Define Endpoint
endpointurl = f'{inat_api_url}/observations?order=desc&order_by=created_at'

# Make the GET request to the API
response = requests.get(endpointurl, headers=headers)

# Put response into a variable
user_info = response.json()
print(user_info)
# Out:
# {'total_results': 197512660, 'page': 1, 'per_page': 30, 'results': [{'quality_grade': 'casual', 'time_observed_at': '2024-04-04T13:26:12-07:00', 'taxon_geoprivacy': None, 'annotations': [], 'uuid': '161ab04f-926d-42c7-bdd6-85b946f38c61', 'observed_on_details': {'date': '2024-04-04', 'day': 4, 'month': 4, 'year': 2024, 'hour': 13, 'week': 14}, 'id': 205437463, 'cached_votes_total': 0, 'identifications_most_agree': False, 'created_at_details': {'date': '2024-04-04', 'day': 4, 'month': 4, 'year': 2024, 'hour': 15, 'week': 14}, 'species_guess': None, 'identifications_most_disagree': False, 'tags': [], 'positional_accuracy': 5, 'comments_count': 0, 'site_id': 17, 'created_time_zone': 'America/Los_Angeles', 'license_code': 'cc-by-nc', 'observed_time_zone': 'America/Los_Angeles', 'quality_metrics': [], 'public_positional_accuracy': 5, 'reviewed_by': [314738], 'oauth_application_id': 3, 'flags': [], 'created_at': '2024-04-04T15:25:40-07:00', 'description': '', 'time_zone_offset': '-08:00', 'project_ids_with_curator_id': [], 'observed_on': '2024-04-04', 'observed_on_string': '2024-04-04 13:26:12-07:00', 'updated_at': '2024-04-04T15:25:40-07:00', 'sounds': [], 'place_ids': [1, 14, 418, 3272, 9853, 51330, 54030, 59613, 62068, 62332, 62622, 63279, 65360, 66741, 92151, 92272, 92337, 93467, 94045, 95504, 96034, 96057, 96683, 96687, 97394, 117811, 118063, 119138, 120714, 124258, 128254, 133886, 150804, 154028], 'captive': False, 'taxon': {'is_active': True, 'ancestry': '48460/47126/211194/47125/47124/47363/47693/788064/788083/53060/1403902', 'min_species_ancestry': '48460,47126,211194,47125,47124,47363,47693,788064,788083,53060,1403902,53059', 'endemic': False, 'iconic_taxon_id': 47126, 'min_species_taxon_id': 53059, 'threatened': False, 'rank_level': 10, 'introduced': False, 'native': True, 'parent_id': 1403902, 'name': 'Galium aparine', 'rank': 'species', 'extinct': False, 'id': 53059, 'ancestor_ids': [48460, 47126, 211194, 47125, 47124, 47363, 47693, 788064, 788083, 53060, 1403902, 53059], 'created_at': '2009-09-12T22:46:59+00:00', 'default_photo': {'id': 79984095, 'license_code': 'cc-by-sa', 'attribution': '(c) Magnus Hagdorn, some rights reserved (CC BY-SA)', 'url': 'https://inaturalist-open-data.s3.amazonaws.com/photos/79984095/square.jpg', 'original_dimensions': {'height': 1356, 'width': 2048}, 'flags': [], 'square_url': 'https://inaturalist-open-data.s3.amazonaws.com/photos/79984095/square.jpg', 'medium_url': 'https://inaturalist-open-data.s3.amazonaws.com/photos/79984095/medium.jpg'}, 'taxon_changes_count': 1, 'taxon_schemes_count': 6, 'observations_count': 74671, 'photos_locked': False, 'universal_search_rank': 74671, 'flag_counts': {'resolved': 1, 'unresolved': 0}, 'current_synonymous_taxon_ids': None, 'atlas_id': None, 'complete_species_count': None, 'wikipedia_url': 'http://en.wikipedia.org/wiki/Galium_aparine', 'iconic_taxon_name': 'Plantae', 'preferred_common_name': 'catchweed bedstraw'}, 'ident_taxon_ids': [48460, 47126, 211194, 47125, 47124, 47363, 47693, 788064, 788083, 53060, 1403902, 53059], 'outlinks': [], 'faves_count': 0, 'ofvs': [], 'num_identification_agreements': 0, 'preferences': {'prefers_community_taxon': None}, 'comments': [], 'map_scale': None, 'uri': 'https://www.inaturalist.org/observations/205437463', 'project_ids': [], 'community_taxon_id': None, 'geojson': {'type': 'Point', 'coordinates': [-121.9115616667, 36.9717916667]}, 'owners_identification_from_vision': True, 'identifications_count': 0, 'obscured': False, 'num_identification_disagreements': 0, 'geoprivacy': None, 'location': '36.9717916667,-121.9115616667', 'votes': [], 'spam': False, 'user': {'id': 314738, 'login': 'vireosylva', 'spam': False, 'suspended': False, 'created_at': '2016-08-27T03:04:17+00:00', 'site_id': 17, 'login_autocomplete': 'vireosylva', 'login_exact': 'vireosylva', 'name': 'Jasper Barnes', 'name_autocomplete': 'Jasper Barnes', 'orcid': None, 'icon': 'https://static.inaturalist.org/attachments/users/icons/314738/thumb.jpg?160416675 ...

# %% [markdown]
# You can continue to explore your new API connection created from scratch, or continue to Part 2 steps below:
